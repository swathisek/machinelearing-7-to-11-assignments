# %%
2.2. Problem Statement: Machine Learning 8
In this assignment students have to find the frequency of words in a
webpage. User can use urllib and BeautifulSoup to extract text from
webpage.
Hint:
from bs4 import BeautifulSoup
import urllib.request
import nltk

# %%
from bs4 import BeautifulSoup
import urllib.request
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Chidi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
response = urllib.request.urlopen('http://www.gutenberg.org/files/2663/2663-h/2663-h.htm')
html = response.read()

soup = BeautifulSoup(html,"html5lib")

# %%
soup.title
# Out:
# <title>
#       Minna von Barnhelm, by Gotthold Ephraim Lessing
#     </title>

# %%
soup.title.string
# Out:
# '\n      Minna von Barnhelm, by Gotthold Ephraim Lessing\n    '

# %%
soup.findAll('a')
# Out:
# [<a href="#link2H_4_0001"> INTRODUCTORY NOTE </a>,
#  <a href="#link2H_4_0002"> MINNA VON BARNHELM </a>,
#  <a href="#link2H_4_0003"> DRAMATIS PERSONAE </a>,
#  <a href="#link2H_4_0004"> ACT I. </a>,
#  <a href="#link2H_4_0005"> ACT II. </a>,
#  <a href="#link2H_4_0006"> ACT III. </a>,
#  <a href="#link2H_4_0007"> ACT IV. </a>,
#  <a href="#link2H_4_0008"> ACT V. </a>,
#  <a id="link2H_4_0001" name="link2H_4_0001">
#        <!--  H2 anchor --> </a>,
#  <a id="link2H_4_0002" name="link2H_4_0002">
#        <!--  H2 anchor --> </a>,
#  <a id="link2H_4_0003" name="link2H_4_0003">
#        <!--  H2 anchor --> </a>,
#  <a id="link2H_4_0004" name="link2H_4_0004">
#        <!--  H2 anchor --> </a>,
#  <a id="link2H_4_0005" name="link2H_4_0005">
#        <!--  H2 anchor --> </a>,
#  <a id="link2H_4_0006" name="link2H_4_0006">
#        <!--  H2 anchor --> </a>,
#  <a id="link2H_4_0007" name="link2H_4_0007">
#        <!--  H2 anchor --> </a>,
#  <a id="link2H_4_0008" name="link2H_4_0008">
# ...

# %%
text=soup.get_text()

# %%
text
# Out:
# '\n    \n      Minna von Barnhelm, by Gotthold Ephraim Lessing\n    \n    \n    \n    body { margin:5%; background:#faebd0; text-align:justify}\n    P { text-indent: 1em; margin-top: .25em; margin-bottom: .25em; }\n    H1,H2,H3,H4,H5,H6 { text-align: center; margin-left: 15%; margin-right: 15%; }\n    hr  { width: 50%; text-align: center;}\n    .foot { margin-left: 20%; margin-right: 20%; text-align: justify; text-indent: -3em; font-size: 90%; }\n    blockquote {font-size: 97%; font-style: italic; margin-left: 10%; margin-right: 10%;}\n    .mynote    {background-color: #DDE; color: #000; padding: .5em; margin-left: 10%; margin-right: 10%; font-family: sans-serif; font-size: 95%;}\n    .toc       { margin-left: 10%; margin-bottom: .75em;}\n    .toc2      { margin-left: 20%;}\n    div.fig    { display:block; margin:0 auto; text-align:center; }\n    div.middle { margin-left: 20%; margin-right: 20%; text-align: justify; }\n    .figleft   {float: left; margin-left: 0%; margin-right: 1%;}\
# ...

# %%
import re

# %%
tokens=re.findall('\w+',text)
tokens[:15]
# Out:
# ['Minna',
#  'von',
#  'Barnhelm',
#  'by',
#  'Gotthold',
#  'Ephraim',
#  'Lessing',
#  'body',
#  'margin',
#  '5',
#  'background',
#  'faebd0',
#  'text',
#  'align',
#  'justify']

# %%
words = []
for word in tokens:
   words.append(word.lower()) 

print(words[:15])
# Out:
# ['minna', 'von', 'barnhelm', 'by', 'gotthold', 'ephraim', 'lessing', 'body', 'margin', '5', 'background', 'faebd0', 'text', 'align', 'justify']

# %%
nltk.download('stopwords')
stop_words=nltk.corpus.stopwords.words('english')
stop_words[:5]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Chidi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# ['i', 'me', 'my', 'myself', 'we']

# %%
new_words = []
for word in words:
    if word not in stop_words:
        new_words.append(word)
new_words[:15]
# Out:
# ['minna',
#  'von',
#  'barnhelm',
#  'gotthold',
#  'ephraim',
#  'lessing',
#  'body',
#  'margin',
#  '5',
#  'background',
#  'faebd0',
#  'text',
#  'align',
#  'justify',
#  'p']

# %%
import matplotlib.pyplot
import seaborn as sn
# %matplotlib inline

# %%
sn.set(rc={'figure.figsize':(11.8,18.6)})
sn.set_style('darkgrid')
wordfrequency=nltk.FreqDist(new_words)
wordfrequency.plot(15)

# %%
2.3. Problem Statement: Machine Learning 9
In this assignment students have to compress racoon grey scale image into
5 clusters. In the end, visualize both raw and compressed image and look
for quality difference.
The raw image is available in spicy.misc package with the name face.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import scipy.misc
# %matplotlib inline

# %%
#visualize the original image
original_image = scipy.misc.face()
plt.figure(figsize=(15, 5))
plt.imshow(original_image)
print("original image ")
plt.show()

#getting the gray scale of the same image
grey_image = scipy.misc.face(gray=True)
plt.figure(figsize=(15, 5))
plt.imshow(grey_image,cmap=plt.cm.gray)
print("grey scale image")
plt.show()
# Out:
# original image
# grey scale image

# %%
#Compress the gray scale racoon to 5 clusters
no_of_rows=f.shape[0]
no_of_columns=f.shape[1]

# %%
print(no_of_rows)
print(no_of_columns)
# Out:
# 768
# 1024

# %%
#Compressing the grey scale image in to 5 clusters 
image = grey_image.reshape(no_of_rows*no_of_columns,1)
# Out:
# array([[114],
#        [130],
#        [145],
#        ...,
#        [142],
#        [141],
#        [140]], dtype=uint8)

# %%
#Cnstantiation of the kmeans model
kmeans = KMeans(n_clusters = 5)
kmeans.fit(image)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
clusters = np.asarray(kmeans.cluster_centers_) 
labels = np.asarray(kmeans.labels_)  
labels = labels.reshape(no_of_rows,no_of_columns);  
plt.imsave('compressed_racoon.png',labels);

# Visualize the compressed image

image = plt.imread('compressed_racoon.png')
plt.figure(figsize=(15,5))
plt.imshow(image)
plt.show()

# %%
2.4. Problem Statement: Machine Learning 10

In this assignment students have to transform iris data into 3 dimensions
and plot a 3d chart with transformed dimensions and colour each data
point with specific class.
Hint:
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets

# %%
Principal Component Analysis, or PCA, is a dimensionality-reduction method that is often used to reduce the dimensionality of large data sets,
by transforming a large set of variables into a smaller one that still contains most of the information in the large set.

# %%
#  Principal component analysis applied to the iris dataset

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


from sklearn import decomposition
from sklearn import datasets

np.random.seed(5)

centers = [[1, 1], [-1, -1], [1, -1]]
iris = datasets.load_iris()
X = iris.data
y = iris.target

fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=36, azim=134)

plt.cla()
pca = decomposition.PCA(n_components=3)
pca.fit(X)
X = pca.transform(X)

for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean() +1.9 ,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.121, edgecolor='y', facecolor='b'))
# Reorder the labels to have colors matching the cluster results
y = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y,  edgecolor='b')#cmap=plt.cm.nipy_spectral,
          

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()

# %%
2.5. Problem Statement: Machine Learning 11

In this assignment students have to make ARIMA model over shampoo sales
data and check the MSE between predicted and actual value.
Student can download data in .csv format from the following link:

https://datamarket.com/data/set/22r0/sales-of-shampoo-over-a-three-
year-period#!ds =22r0&display=line

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

def parser(x):
    return datetime.strptime('190'+x, '%Y-%m')


series = read_csv('shampoosales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
